# %% [markdown]
# # Homework #2
#
# ## Create a Farm
#
# Old McDonald is dyslexic OIEIE...
# Please help on his farm, please...
#
# Your goal is to categorize all of his animals into groups.
# example:
# - pigs are useful for there meat, skin and help improve the soil and biodiversity
#
# Create classes for all of his different types of animals
# You should have at least 5 animals on the farm ie. cows, pigs, dogs, goats
#
# VERY Poorly written example
#
# ```python
# class Animals (self):
#     self.name = name
#     self.age = age
#
# class Pets(Animals):
#     self.friend = True
#     self.eat = False
#
# class Farm (Animals):
#     self.eat = True #will it be sold for food
#     self.leather = True #will it be sold for leather
#     self.helper = False #will it be used to say plow a field
#     self.soil = True #Will it be used to help the soil
#
# class Dog(Pets)
#     self.good_boy = True
#     self.type = "type of dog"
# listOfAnimals = [Dog()]
# ```
#
#
# Your program should have an input and output allowing the user to add and remove animals.
#
# Love you !

# %%
class animals:
    """class for all animals"""
    def __init__(self, name):
        self.name = name

class farm_animals(animals):
    """class for all farm animals"""
    def __init__(self, name, produce):
        super().__init__(name)
        self.produce = produce

class cow(farm_animals):
    def __init__(self, name):
        super().__init__(name, "milk, meat, leather")

class goat(farm_animals):
    def __init__(self, name):
        super().__init__(name, "milk")

class chicken(farm_animals):
    def __init__(self, name):
        super().__init__(name, "meat, eggs")

class piggy(farm_animals):
    def __init__(self, name):
        super().__init__(name, "bacon")

class sheep(farm_animals):
    def __init__(self, name):
        super().__init__(name, "milk, wool")

def add_animal():
    while True:
        animal_input = input("Enter animal to add: ")
        if animal_input in ["cow", "pig", "goat", "chicken", "sheep", "horse", "duck", "turkey", "donkey", "bee"]:
            break
        else:
            print("Invalid animal type. Please choose from the list.")

    name = input("Enter animal name: ")

    if animal_input == "cow":
        farm_animals.append(cow(name))
    elif animal_input == "pig":
        farm_animals.append(piggy(name))
    elif animal_input == "goat":
        farm_animals.append(goat(name))
    elif animal_input == "chicken":
        farm_animals.append(chicken(name))
    elif animal_input == "sheep":
        farm_animals.append(sheep(name))
